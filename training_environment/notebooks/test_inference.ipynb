# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../')
from utils.inference import translator
# Out:
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'multi_head_attention' (of type MultiHeadAttention) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'encoder_layer' (of type EncoderLayer) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'encoder_layer_1' (of type EncoderLayer) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'encoder_layer_2' (of type EncoderLayer) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'encoder_layer_3' (of type EncoderLayer) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'encoder_layer_4' (of type EncoderLayer) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'encoder_layer_5' (of type EncoderLayer) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'multi_head_attention_6' (of type MultiHeadAttention) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'multi_head_attention_7' (of type MultiHeadAttention) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'decoder_layer' (of type DecoderLayer) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'multi_head_attention_8' (of type MultiHeadAttention) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'multi_head_attention_9' (of type MultiHeadAttention) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'multi_head_attention_10' (of type MultiHeadAttention) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'multi_head_attention_11' (of type MultiHeadAttention) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'multi_head_attention_12' (of type MultiHeadAttention) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'multi_head_attention_13' (of type MultiHeadAttention) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'multi_head_attention_14' (of type MultiHeadAttention) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'multi_head_attention_15' (of type MultiHeadAttention) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'multi_head_attention_16' (of type MultiHeadAttention) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice_ML\EN_VI_Translate_System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'multi_head_attention_17' (of type MultiHeadAttention) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Tải thành công trọng số tại: ../checkpoints/transformer_best_model.weights.h5

# %%
print(translator.translate("I go to school"))
# Out:
# Tôi đi học.

# %%
test=[
    "I am playing games while my mother is cooking",
    "As of the 2026 World Cup, 23 tournaments have been held since the event's inception in 1930, and a total of 84 national teams have competed",
    "The tiger is an apex predator and preys mainly on hooved mammals, which it takes by ambush"
]

for t in test:
    print(translator.translate(t))
# Out:
# Tôi đang chơi game khi mẹ đang nấu ăn.
# Vào năm 20, 23 giải thưởng thế giới đã được tổ chức từ năm 30, và tổng cộng là  ⁇ 2 quốc gia đang thi đấu.
# Loài hổ là loài động vật ăn thịt đỉnh và con mồi chủ yếu là động vật có vú không hài lòng, và nó sẽ bị phục kích.

# %%
print(translator.translate("The competition consists of six problems. The competition is held over two consecutive days with three problems each; each day, the contestants have four-and-a-half hours to solve three problems. Each problem is worth 7 points for a maximum total score of 42 points"))
# Out:
# Sự cạnh tranh bao gồm 6 vấn đề, sự cạnh tranh được tổ chức trong vòng 2 ngày liên tiếp với 3 vấn đề mỗi ngày; mỗi ngày, các thí sinh có bốn giờ đồng hồ để giải quyết 3 vấn đề, mỗi vấn đề là 7 điểm để đạt được tối đa 8 điểm.
