# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../')
from utils.inference import translator
# Out:
# d:\Practice ML\EN VI Translate System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'multi_head_attention' (of type MultiHeadAttention) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# d:\Practice ML\EN VI Translate System\.venv\Lib\site-packages\keras\src\layers\layer.py:1039: UserWarning: Layer 'encoder_layer' (of type EncoderLayer) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# ...

# %%
print(translator.translate("I go to school"))
# Out:
# Tôi đi học.

# %%
test=[
    "I am playing games while my mother is cooking",
    "As of the 2026 World Cup, 23 tournaments have been held since the event's inception in 1930, and a total of 84 national teams have competed"
]

for t in test:
    print(translator.translate(t))
# Out:
# Tôi đang chơi game trong khi đang nấu ăn.
# Trong năm 206, 23 giải đấu đã được tổ chức từ khi sự kiện diễn ra vào năm 1930, và tổng cộng là 250 đội tuyển quốc gia đã tranh đấu.
